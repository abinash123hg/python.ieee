# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.tree import plot_tree
# Load the dataset (update path if needed)
data = pd.read_csv(r"C:\Users\VICTUS\Downloads\Students Social Media Addiction (2) (1).csv")
# Drop columns we don't need
data = data.drop(['Student_ID', 'Affects_Academic_Performance', 
                  'Conflicts_Over_Social_Media', 'Addicted_Score'], axis=1)
# Show first few rows to check data
print("First 5 Rows of Data:")
print(data.head())
# Features (X) and target (y = Mental Health Score)
X = data.drop('Mental_Health_Score', axis=1)
y = data['Mental_Health_Score']
# Convert categorical columns (Gender, Country, etc.) to numbers
categorical_cols = ['Gender', 'Academic_Level', 'Country', 'Most_Used_Platform', 'Relationship_Status']
encoder = OneHotEncoder(sparse_output=False, drop='first')  # Simple encoding, drop first to avoid dummy trap
X_encoded = encoder.fit_transform(X[categorical_cols])
encoded_cols = encoder.get_feature_names_out(categorical_cols)
X_encoded_df = pd.DataFrame(X_encoded, columns=encoded_cols)
# Combine encoded categorical with numerical columns
numerical_cols = ['Age', 'Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night']
X_numerical = X[numerical_cols]
X_final = pd.concat([X_numerical.reset_index(drop=True), X_encoded_df.reset_index(drop=True)], axis=1)
# Split data: 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)
# Train Random Forest model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Make predictions
y_pred = model.predict(X_test)
# Calculate metrics
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print("\nModel Results:")
print(f"R² Score: {r2:.4f} (how well model fits data)")
print(f"MAE: {mae:.4f} (average prediction error)")
# Save metrics for paper
results = pd.DataFrame({
    'Model': ['Random Forest'],
    'R²': [r2],
    'MAE': [mae]
})
results.to_csv('model_results.csv', index=False)
print("\nResults saved to 'model_results.csv'")
# Feature importance plot
feature_names = X_final.columns
importances = model.feature_importances_
feat_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances}).sort_values('Importance', ascending=False).head(5)
plt.figure(figsize=(8, 5))
sns.barplot(x='Importance', y='Feature', data=feat_df)
plt.title('Top 5 Features Affecting Mental Health Score')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('feature_importance.png')
plt.show()
# Plot one decision tree (first tree from Random Forest)
plt.figure(figsize=(15, 10))
plot_tree(model.estimators_[0], feature_names=feature_names, filled=True, rounded=True, max_depth8=5)
plt.title('Decision Tree from Random Forest Model')
plt.savefig('decision_tree.png')
plt.show()
# Sample predictions for presentation
sample_df = pd.DataFrame({
    'Actual Mental Health Score': y_test[:5].values,
    'Predicted Score': y_pred[:5].round(2)
})
print("\nSample Predictions:")
print(sample_df)
sample_df.to_csv('sample_predictions.csv', index=False)
# Out:
# First 5 Rows of Data:
#    Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0   19  Female  Undergraduate  Bangladesh                    5.2
# 1   22    Male       Graduate       India                    2.1
# 2   20  Female  Undergraduate         USA                    6.0
# 3   18    Male    High School          UK                    3.0
# 4   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform  Sleep_Hours_Per_Night  Mental_Health_Score  \
# 0          Instagram                    6.5                    6
# 1            Twitter                    7.5                    8
# 2             TikTok                    5.0                    5
# 3            YouTube                    7.0                    7
# 4           Facebook                    6.0                    6
#
#   Relationship_Status
# 0     In Relationship
# 1              Single
# 2         Complicated
# 3              Single
# 4     In Relationship
#
# Model Results:
# R² Score: 0.9228 (how well model fits data)
# MAE: 0.1499 (average prediction error)
#
# Results saved to 'model_results.csv'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 65
#      63 # Plot one decision tree (first tree from Random Forest)
#      64 plt.figure(figsize=(15, 10))
# ---> 65 plot_tree(model.estimators_[0], feature_names=feature_names, filled=True, rounded=True, max_depth8=5)
#      66 plt.title('Decision Tree from Random Forest Model')
#      67 plt.savefig('decision_tree.png')
#
# File c:\Users\VICTUS\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File c:\Users\VICTUS\anaconda3\Lib\inspect.py:3267, in Signature.bind(self, *args, **kwargs)
#    3262 def bind(self, /, *args, **kwargs):
#    3263     """Get a BoundArguments object, that maps the passed `args`
#    3264     and `kwargs` to the function's signature.  Raises `TypeError`
#    3265     if the passed arguments can not be bound.
#    3266     """
# -> 3267     return self._bind(args, kwargs)
#
# File c:\Users\VICTUS\anaconda3\Lib\inspect.py:3256, in Signature._bind(self, args, kwargs, partial)
#    3246         raise TypeError(
#    3247             'got some positional-only arguments passed as '
#    3248             'keyword arguments: {arg!r}'.format(
#    (...)
#    3253             ),
#    3254         )
#    3255     else:
# -> 3256         raise TypeError(
#    3257             'got an unexpected keyword argument {arg!r}'.format(
#    3258                 arg=next(iter(kwargs))))
#    3260 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'max_depth8'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# [Your data load from chosen code]
data = pd.read_csv(r"C:\Users\VICTUS\Downloads\Students Social Media Addiction (2) (1).csv")
data = data.drop(['Student_ID', 'Affects_Academic_Performance', 
                  'Conflicts_Over_Social_Media', 'Addicted_Score'], axis=1)
print("First 5 Rows of Data:")
print(data.head())

# --- EDA 1: Dataset Info & Summary Stats ---
# Purpose: Show size, types, and stats. Confirms clean data for IEEE Methods section.
print("\n=== EDA 1: Dataset Overview ===")
print("Shape:", data.shape)
print("\nData Types:")
print(data.dtypes)
print("\nNumerical Stats:")
numerical_cols = ['Age', 'Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night', 'Mental_Health_Score']
print(data[numerical_cols].describe())
print("\nMissing Values:")
print(data.isnull().sum())
# Expected: (705, 9), no nulls, MH score mean ~6.23, usage ~4.92 hrs.
# Insight: "Dataset has 705 samples, no missing values, with MH scores averaging 6.23 (std 1.11)."

# --- EDA 2: Categorical Distributions ---
# Purpose: Bar plot for key categorical (Most_Used_Platform). Shows platform popularity for paper.
print("\n=== EDA 2: Categorical Distributions ===")
platform_counts = data['Most_Used_Platform'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(platform_counts.index, platform_counts.values, color='lightblue', edgecolor='black')
plt.title('Most Used Social Media Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Students')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('eda_platform_bar.png')
plt.show()
print("Plot saved: 'eda_platform_bar.png'")
# Expected: Instagram (~249) tops, then TikTok (~154), Facebook (~123).
# Insight: "Instagram dominates (35% of users), suggesting its impact on teen MH."

# --- EDA 3: Mental Health Score Distribution ---
# Purpose: Histogram of target. Shows score spread for Results section.
print("\n=== EDA 3: Mental Health Score Distribution ===")
plt.figure(figsize=(8, 5))
plt.hist(data['Mental_Health_Score'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribution of Mental Health Scores')
plt.xlabel('Mental Health Score (4-9)')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.3)
plt.savefig('eda_mh_distribution.png')
plt.show()
print("Plot saved: 'eda_mh_distribution.png'")
# Expected: Peak at 6 (~200 students), skewed right (few 8-9 scores).
# Insight: "Most teens score 5-7, indicating moderate mental health, with few extreme cases."

# --- EDA 4: Correlation Heatmap ---
# Purpose: Numerical correlations. Highlights usage-MH link for Discussion.
print("\n=== EDA 4: Correlation Heatmap ===")
corr_matrix = data[numerical_cols].corr()
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1)
ax.set_xticks(np.arange(len(numerical_cols)))
ax.set_yticks(np.arange(len(numerical_cols)))
ax.set_xticklabels(numerical_cols, rotation=45, ha='right')
ax.set_yticklabels(numerical_cols)
for i in range(len(numerical_cols)):
    for j in range(len(numerical_cols)):
        ax.text(j, i, f'{corr_matrix.iloc[i, j]:.2f}', ha='center', va='center', color='black')
plt.colorbar(im)
plt.title('Correlation Matrix of Numerical Features')
plt.tight_layout()
plt.savefig('eda_correlation_heatmap.png')
plt.show()
print("Plot saved: 'eda_correlation_heatmap.png'")
# Expected: Usage-MH corr ~-0.31, Sleep-MH ~0.15, Age-MH weak (~0.05).
# Insight: "Negative correlation (-0.31) between usage hours and MH score suggests heavy social media use predicts poorer mental health."

# --- EDA 5: Box Plot of Usage by MH Score ---
# Purpose: Shows usage spread per score. Justifies model focus on usage.
print("\n=== EDA 5: Usage Hours by Mental Health Score ===")
fig, ax = plt.subplots(figsize=(8, 5))
scores = sorted(data['Mental_Health_Score'].unique())
usage_by_score = [data[data['Mental_Health_Score'] == score]['Avg_Daily_Usage_Hours'] for score in scores]
ax.boxplot(usage_by_score, labels=scores, patch_artist=True, 
           boxprops=dict(facecolor='lightblue', color='black'))
ax.set_title('Social Media Usage by Mental Health Score')
ax.set_xlabel('Mental Health Score')
ax.set_ylabel('Avg Daily Usage Hours')
plt.grid(axis='y', alpha=0.3)
plt.savefig('eda_usage_boxplot.png')
plt.show()
print("Plot saved: 'eda_usage_boxplot.png'")
# Expected: Score 4-5: median ~5.5 hrs, score 8-9: ~3.5 hrs.
# Insight: "Lower MH scores have higher median usage, with outliers in heavy use."

# --- EDA 6: Scatter Plot of Usage vs MH Score ---
# Purpose: Visualizes key relationship. Supports RF feature importance (usage ~45%).
print("\n=== EDA 6: Usage vs Mental Health Score ===")
plt.figure(figsize=(8, 5))
plt.scatter(data['Avg_Daily_Usage_Hours'], data['Mental_Health_Score'], 
            color='green', alpha=0.6, s=50)
z = np.polyfit(data['Avg_Daily_Usage_Hours'], data['Mental_Health_Score'], 1)
p = np.poly1d(z)
plt.plot(data['Avg_Daily_Usage_Hours'], p(data['Avg_Daily_Usage_Hours']), "r--", alpha=0.8)
plt.title('Social Media Usage vs Mental Health Score')
plt.xlabel('Avg Daily Usage Hours')
plt.ylabel('Mental Health Score')
plt.grid(True, alpha=0.3)
plt.savefig('eda_usage_scatter.png')
plt.show()
print("Plot saved: 'eda_usage_scatter.png'")
# Expected: Downward trend (more hours → lower score), slope ~-0.3.
# Insight: "Scatter with trend line confirms higher social media usage linked to lower mental health scores."
# Out:
# First 5 Rows of Data:
#    Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0   19  Female  Undergraduate  Bangladesh                    5.2
# 1   22    Male       Graduate       India                    2.1
# 2   20  Female  Undergraduate         USA                    6.0
# 3   18    Male    High School          UK                    3.0
# 4   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform  Sleep_Hours_Per_Night  Mental_Health_Score  \
# 0          Instagram                    6.5                    6
# 1            Twitter                    7.5                    8
# 2             TikTok                    5.0                    5
# 3            YouTube                    7.0                    7
# 4           Facebook                    6.0                    6
#
#   Relationship_Status
# 0     In Relationship
# 1              Single
# 2         Complicated
# 3              Single
# 4     In Relationship
#
# === EDA 1: Dataset Overview ===
# Shape: (705, 9)
#
# Data Types:
# Age                        int64
# Gender                    object
# Academic_Level            object
# Country                   object
# Avg_Daily_Usage_Hours    float64
# Most_Used_Platform        object
# Sleep_Hours_Per_Night    float64
# Mental_Health_Score        int64
# Relationship_Status       object
# dtype: object
#
# Numerical Stats:
#               Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000             705.000000             705.000000
# mean    20.659574               4.918723               6.868936
# std      1.399217               1.257395               1.126848
# min     18.000000               1.500000               3.800000
# 25%     19.000000               4.100000               6.000000
# 50%     21.000000               4.800000               6.900000
# 75%     22.000000               5.800000               7.700000
# max     24.000000               8.500000               9.600000
#
#        Mental_Health_Score
# count           705.000000
# mean              6.226950
# std               1.105055
# min               4.000000
# 25%               5.000000
# 50%               6.000000
# 75%               7.000000
# max               9.000000
#
# Missing Values:
# Age                      0
# Gender                   0
# Academic_Level           0
# Country                  0
# Avg_Daily_Usage_Hours    0
# Most_Used_Platform       0
# Sleep_Hours_Per_Night    0
# Mental_Health_Score      0
# Relationship_Status      0
# dtype: int64
#
# === EDA 2: Categorical Distributions ===
# Plot saved: 'eda_platform_bar.png'
#
# === EDA 3: Mental Health Score Distribution ===
# Plot saved: 'eda_mh_distribution.png'
#
# === EDA 4: Correlation Heatmap ===
# Plot saved: 'eda_correlation_heatmap.png'
#
# === EDA 5: Usage Hours by Mental Health Score ===
# Plot saved: 'eda_usage_boxplot.png'
#
# === EDA 6: Usage vs Mental Health Score ===
# Plot saved: 'eda_usage_scatter.png'

# %% [markdown]
# 1. Import Required Libraries
#
# Purpose: Loads libraries for data processing, visualization, and machine learning. Relevance: Sets up tools for analyzing the 705-student dataset and building the Random Forest model, ensuring IEEE reproducibility. Expected Output: No output—just imports. Presentation: “We used standard Python libraries like pandas and sklearn, taught in our ML course, to process teen social media data.”

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.tree import plot_tree

# %% [markdown]
# 2. Load the Dataset

# %%
data = pd.read_csv(r"C:\Users\VICTUS\Downloads\Students Social Media Addiction (2) (1).csv")

# %% [markdown]
# 3. Drop Unnecessary Columns
#
# The dataframe has 9 columns, which include Age, Gender, and Mental_Health_Score. We removed IDs and unrelated columns to focus on social media and health factors.

# %%
data = data.drop(['Student_ID', 'Affects_Academic_Performance', 
                  'Conflicts_Over_Social_Media', 'Addicted_Score'], axis=1)

# %%
print("First 5 Rows of Data:")
print(data.head())
# Out:
# First 5 Rows of Data:
#    Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0   19  Female  Undergraduate  Bangladesh                    5.2
# 1   22    Male       Graduate       India                    2.1
# 2   20  Female  Undergraduate         USA                    6.0
# 3   18    Male    High School          UK                    3.0
# 4   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform  Sleep_Hours_Per_Night  Mental_Health_Score  \
# 0          Instagram                    6.5                    6
# 1            Twitter                    7.5                    8
# 2             TikTok                    5.0                    5
# 3            YouTube                    7.0                    7
# 4           Facebook                    6.0                    6
#
#   Relationship_Status
# 0     In Relationship
# 1              Single
# 2         Complicated
# 3              Single
# 4     In Relationship

# %% [markdown]
# Dataset Overview

# %%
print("Shape:", data.shape)
print(data.info())
print(data.describe())
print(data.isnull().sum())
# Out:
# Shape: (705, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    705 non-null    int64
#  1   Gender                 705 non-null    object
#  2   Academic_Level         705 non-null    object
#  3   Country                705 non-null    object
#  4   Avg_Daily_Usage_Hours  705 non-null    float64
#  5   Most_Used_Platform     705 non-null    object
#  6   Sleep_Hours_Per_Night  705 non-null    float64
#  7   Mental_Health_Score    705 non-null    int64
#  8   Relationship_Status    705 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 49.7+ KB
# None
#               Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000             705.000000             705.000000
# mean    20.659574               4.918723               6.868936
# std      1.399217               1.257395               1.126848
# min     18.000000               1.500000               3.800000
# 25%     19.000000               4.100000               6.000000
# 50%     21.000000               4.800000               6.900000
# 75%     22.000000               5.800000               7.700000
# max     24.000000               8.500000               9.600000
#
#        Mental_Health_Score
# count           705.000000
# mean              6.226950
# std               1.105055
# min               4.000000
# 25%               5.000000
# 50%               6.000000
# 75%               7.000000
# max               9.000000
# Age                      0
# Gender                   0
# Academic_Level           0
# Country                  0
# Avg_Daily_Usage_Hours    0
# Most_Used_Platform       0
# Sleep_Hours_Per_Night    0
# Mental_Health_Score      0
# Relationship_Status      0
# dtype: int64

# %% [markdown]
# Categorical Distributions

# %%
import matplotlib.pyplot as plt
platform_counts = data['Most_Used_Platform'].value_counts()
plt.figure(figsize=(12,7))
plt.bar(platform_counts.index, platform_counts.values, color="skyblue", edgecolor="black")
plt.title("Most Used Social Media Platforms", fontsize=15)
plt.xlabel("Platform", fontsize=14)
plt.ylabel("Number of Students", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart shows that Instagram, TikTok, and Facebook are the platforms most popular with students.

# %% [markdown]
# 7.Mental Health Score Distribution

# %%
plt.figure(figsize=(10,6)) 
plt.hist(data['Mental_Health_Score'], bins=10, color='skyblue',edgecolor='black')
plt.title("Distribution of Mental Health Scores", fontsize=16)
plt.xlabel("Mental Health Score", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.show()

# %% [markdown]
# "This histogram displays the distribution of students' mental health scores throughout the dataset."

# %% [markdown]
# 8. EDA: Correlation Heatmap

# %%
corr = data[numerical_cols].corr()
plt.figure(figsize=(8,6))
plt.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(len(numerical_cols)), numerical_cols, rotation=90)
plt.yticks(range(len(numerical_cols)), numerical_cols)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# This heatmap shows the relationship between social media use, hours of sleep, age, and mental health scores.

# %% [markdown]
# 9. EDA: Usage Hours by Mental Health Score

# %%
scores = sorted(data['Mental_Health_Score'].unique())
usage_by_score = [data[data['Mental_Health_Score'] == s]['Avg_Daily_Usage_Hours'] for s in scores]
plt.boxplot(usage_by_score, labels=scores)
plt.title("Social Media Usage by Mental Health Score")
plt.xlabel("Mental Health Score")
plt.ylabel("Avg Daily Usage Hours")
plt.show()

# %% [markdown]
# This boxplot shows how students' average daily social media use changes with their mental health scores.

# %% [markdown]
# 10. EDA: Usage vs Mental Health Score

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(data['Avg_Daily_Usage_Hours'], data['Mental_Health_Score'], color='green', alpha=0.6)
m, b = np.polyfit(data['Avg_Daily_Usage_Hours'], data['Mental_Health_Score'], 1)
plt.plot(data['Avg_Daily_Usage_Hours'], m*data['Avg_Daily_Usage_Hours'] + b, "r--")
plt.xlabel('Avg Daily Usage Hours')
plt.ylabel('Mental Health Score')
plt.title('Social Media Usage vs Mental Health Score')
plt.show()

# %% [markdown]
# “This scatter plot shows the relationship between daily social media usage and mental health scores.”

# %% [markdown]
# 11. Define Features (X) and Target (y)

# %%
X = data.drop('Mental_Health_Score', axis=1)
y = data['Mental_Health_Score']

# %% [markdown]
# 12. Define the categorical columns

# %%
categorical_cols = ['Gender','Academic_Level','Country','Most_Used_Platform','Relationship_Status']

# %% [markdown]
# 13. Initialize and Fit OneHotEncoder

# %%
encoder = OneHotEncoder(sparse_output=False, drop='first')
X_encoded = encoder.fit_transform(X[categorical_cols])

# %% [markdown]
# 14. Encoded column names and create dataFrame

# %%
encoded_cols = encoder.get_feature_names_out(categorical_cols)
X_encoded_df = pd.DataFrame(X_encoded, columns=encoded_cols)

# %% [markdown]
# 15. Define Numerical Columns

# %%
X_numerical = X[numerical_cols]

# %% [markdown]
# 16. Extract Numerical Features

# %%
X_numerical = X[numerical_cols]

# %% [markdown]
# 17. Combine Encoded Categorical and Numerical Features

# %%
X_final = pd.concat([X_numerical.reset_index(drop=True),
X_encoded_df.reset_index(drop=True)], axis=1)

# %% [markdown]
# 18. Split Data into Train and Test Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# %% [markdown]
# 19. Initialize and Train Random Forest Model

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# 20. Predictions on test set

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# 21. Calculate Metrics

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print("\nmodel results:")
print(f"R² Score: {r2:f} ")
print(f"MAE: {mae:f} ")
# Out:
# model results:
# R² Score: 0.922824
# MAE: 0.149858

# %%
importances = model.feature_importances_
feat_df = pd.DataFrame({'Feature': X_final.columns, 'Importance': importances}).sort_values(by='Importance', ascending=False).head(5)
print(feat_df)
# Out:
#                   Feature  Importance
# 2   Sleep_Hours_Per_Night    0.454798
# 1   Avg_Daily_Usage_Hours    0.290234
# 78       Country_Pakistan    0.037315
# 15     Country_Bangladesh    0.031008
# 95          Country_Spain    0.016368

# %% [markdown]
# “These are the top 5 predictors of mental health scores.”

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='Importance', y='Feature', data=feat_df)
plt.title('Top 5 Features Affecting Mental Health Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# "Usage hours and sleep are the main factors that predict mental health scores."

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(35, 25)) 
plot_tree(model.estimators_[0],feature_names=X_final.columns,filled=True, rounded=True, max_depth=4,fontsize=14,proportion=True)
plt.show()

# %% [markdown]
# “This decision tree shows how the model uses important features such as usage hours and sleep to predict mental health scores.”

# %% [markdown]
# 28. Print Sample Predictions

# %%
print("\nSample Predictions:")
print(sample_df)
# Out:
# Sample Predictions:
#    Actual Mental Health Score  Predicted Score
# 0                           7             7.00
# 1                           6             5.99
# 2                           7             7.14
# 3                           5             5.04
# 4                           8             8.00
